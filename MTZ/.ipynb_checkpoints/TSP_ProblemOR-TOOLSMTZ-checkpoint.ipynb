# %% [markdown]
# ## Travelling Salesman problem

# %%
# %matplotlib widget
from IPython.display import display, HTML
display(HTML("<style>.container{width:100% !important;}</style>"))
# Out:
# <style>.container{width:100% !important;}</style>

# %%
# !pip install ortools
# Out:
# Requirement already satisfied: ortools in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (9.10.4067)
# Requirement already satisfied: absl-py>=2.0.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from ortools) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from ortools) (1.26.4)
# Requirement already satisfied: pandas>=2.0.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from ortools) (2.1.4)
# Requirement already satisfied: protobuf>=5.26.1 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from ortools) (5.27.1)
# Requirement already satisfied: immutabledict>=3.0.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from ortools) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from pandas>=2.0.0->ortools) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from pandas>=2.0.0->ortools) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from pandas>=2.0.0->ortools) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.16.0)

# %% [markdown]
# Lets start step by step.
# Your first task is the following.
# Choose five cities and store them as strings in a list `cities`. Also define a dictionary `distances` with distances between the cities. The distances do not have to be realistic.

# %% [markdown]
# ## Generate the Dataset

# %%
# !pip install dwave-ocean-sdk
# Out:
# Requirement already satisfied: dwave-ocean-sdk in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (7.0.0)
# Requirement already satisfied: dimod==0.12.15 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (0.12.15)
# Requirement already satisfied: dwave-cloud-client==0.12.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (0.12.0)
# Requirement already satisfied: dwave-greedy==0.3.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (0.3.0)
# Requirement already satisfied: dwave-hybrid==0.6.11 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (0.6.11)
# Requirement already satisfied: dwave-inspector==0.5.0.post0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (0.5.0.post0)
# Requirement already satisfied: dwave-neal==0.6.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (0.6.0)
# Requirement already satisfied: dwave-networkx==0.8.15 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (0.8.15)
# Requirement already satisfied: dwave-optimization==0.1.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (0.1.0)
# Requirement already satisfied: dwave-preprocessing==0.6.5 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (0.6.5)
# Requirement already satisfied: dwave-samplers==1.2.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (1.2.0)
# Requirement already satisfied: dwave-system==1.25.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (1.25.0)
# Requirement already satisfied: dwave-tabu==0.5.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (0.5.0)
# Requirement already satisfied: dwavebinarycsp==0.3.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (0.3.0)
# Requirement already satisfied: minorminer==0.2.14 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (0.2.14)
# Requirement already satisfied: penaltymodel==1.1.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-ocean-sdk) (1.1.0)
# Requirement already satisfied: numpy<2.0.0,>=1.17.3 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dimod==0.12.15->dwave-ocean-sdk) (1.26.4)
# Requirement already satisfied: requests<3,>=2.25 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from requests[socks]<3,>=2.25->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client==0.12.0->dwave-ocean-sdk) (2.2.1)
# Requirement already satisfied: pydantic<3,>=2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client==0.12.0->dwave-ocean-sdk) (2.7.4)
# Requirement already satisfied: homebase<2,>=1.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client==0.12.0->dwave-ocean-sdk) (1.0.1)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client==0.12.0->dwave-ocean-sdk) (8.1.7)
# Requirement already satisfied: python-dateutil<3,>=2.7 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client==0.12.0->dwave-ocean-sdk) (2.9.0)
# Requirement already satisfied: plucky<0.5,>=0.4.3 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client==0.12.0->dwave-ocean-sdk) (0.4.3)
# Requirement already satisfied: diskcache<6,>=5.2.1 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client==0.12.0->dwave-ocean-sdk) (5.6.3)
# Requirement already satisfied: packaging>=19 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client==0.12.0->dwave-ocean-sdk) (24.0)
# Requirement already satisfied: werkzeug<4,>=2.2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client==0.12.0->dwave-ocean-sdk) (3.0.3)
# Requirement already satisfied: typing-extensions<5,>=4.5.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client==0.12.0->dwave-ocean-sdk) (4.12.1)
# Requirement already satisfied: authlib<2,>=1.2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client==0.12.0->dwave-ocean-sdk) (1.3.1)
# Requirement already satisfied: importlib-metadata>=5.0.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client==0.12.0->dwave-ocean-sdk) (7.1.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-hybrid==0.6.11->dwave-ocean-sdk) (2.8.8)
# Requirement already satisfied: Flask<4,>=2.2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-inspector==0.5.0.post0->dwave-ocean-sdk) (3.0.3)
# Requirement already satisfied: orjson>=3.10.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-inspector==0.5.0.post0->dwave-ocean-sdk) (3.10.4)
# Requirement already satisfied: scipy>=1.7.3 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-system==1.25.0->dwave-ocean-sdk) (1.11.4)
# Requirement already satisfied: fasteners>=0.15 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from minorminer==0.2.14->dwave-ocean-sdk) (0.19)
# Requirement already satisfied: cryptography in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from authlib<2,>=1.2->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (42.0.7)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from Flask<4,>=2.2->dwave-inspector==0.5.0.post0->dwave-ocean-sdk) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from Flask<4,>=2.2->dwave-inspector==0.5.0.post0->dwave-ocean-sdk) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from Flask<4,>=2.2->dwave-inspector==0.5.0.post0->dwave-ocean-sdk) (1.8.2)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from importlib-metadata>=5.0.0->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (3.17.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from pydantic<3,>=2->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from pydantic<3,>=2->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (2.18.4)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from python-dateutil<3,>=2.7->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from requests[socks]<3,>=2.25->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (1.7.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from werkzeug<4,>=2.2->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (2.1.5)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from cryptography->authlib<2,>=1.2->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from cffi>=1.12->cryptography->authlib<2,>=1.2->dwave-cloud-client==0.12.0->dwave-ocean-sdk) (2.22)

# %%
# !pip install dimod dwave-system
# Out:
# Requirement already satisfied: dimod in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (0.12.15)
# Requirement already satisfied: dwave-system in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (1.25.0)
# Requirement already satisfied: numpy<2.0.0,>=1.17.3 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dimod) (1.26.4)
# Requirement already satisfied: dwave-optimization<0.3,>=0.1.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-system) (0.1.0)
# Requirement already satisfied: dwave-cloud-client<0.13.0,>=0.12.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-system) (0.12.0)
# Requirement already satisfied: dwave-networkx>=0.8.10 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-system) (0.8.15)
# Requirement already satisfied: dwave-preprocessing>=0.5.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-system) (0.6.5)
# Requirement already satisfied: homebase<2.0.0,>=1.0.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-system) (1.0.1)
# Requirement already satisfied: minorminer<0.3.0,>=0.2.8 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-system) (0.2.14)
# Requirement already satisfied: dwave-samplers>=1.0.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-system) (1.2.0)
# Requirement already satisfied: scipy>=1.7.3 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-system) (1.11.4)
# Requirement already satisfied: requests<3,>=2.25 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from requests[socks]<3,>=2.25->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (2.2.1)
# Requirement already satisfied: pydantic<3,>=2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (2.7.4)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (8.1.7)
# Requirement already satisfied: python-dateutil<3,>=2.7 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (2.9.0)
# Requirement already satisfied: plucky<0.5,>=0.4.3 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (0.4.3)
# Requirement already satisfied: diskcache<6,>=5.2.1 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (5.6.3)
# Requirement already satisfied: packaging>=19 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (24.0)
# Requirement already satisfied: werkzeug<4,>=2.2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (3.0.3)
# Requirement already satisfied: typing-extensions<5,>=4.5.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (4.12.1)
# Requirement already satisfied: authlib<2,>=1.2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (1.3.1)
# Requirement already satisfied: importlib-metadata>=5.0.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (7.1.0)
# Requirement already satisfied: networkx>=2.4 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from dwave-networkx>=0.8.10->dwave-system) (2.8.8)
# Requirement already satisfied: fasteners>=0.15 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from minorminer<0.3.0,>=0.2.8->dwave-system) (0.19)
# Requirement already satisfied: cryptography in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from authlib<2,>=1.2->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (42.0.7)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from importlib-metadata>=5.0.0->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (3.17.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from pydantic<3,>=2->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from pydantic<3,>=2->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (2.18.4)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from python-dateutil<3,>=2.7->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from requests[socks]<3,>=2.25->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (1.7.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from werkzeug<4,>=2.2->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (2.1.5)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from cryptography->authlib<2,>=1.2->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/expertcourse/lib/python3.10/site-packages (from cffi>=1.12->cryptography->authlib<2,>=1.2->dwave-cloud-client<0.13.0,>=0.12.0->dwave-system) (2.22)

# %%
from IPython.display import display, HTML

import random
import numpy as np
import itertools
import time
from ortools.linear_solver import pywraplp

random.seed(42)
cities = [
    "Munich", "Hamburg", "Stuttgart", "Berlin", "Frankfurt", 
    "Paris", "Madrid", "Barcelona", "Tenerife", "Malaga", 
    "Valencia", "Sevilla", "Lisboa", "Roma", 
    "London", "Brussels", "Amsterdam", "Zurich", "Vienna", 
    "Prague", "Warsaw", "Budapest", "Athens", "Dublin", 
    "Copenhagen", "Oslo", "Stockholm", "Helsinki", "Reykjavik", 
    "Milan", "Venice", "Naples", "Florence", "Turin", 
    "Nice", "Lyon", "Marseille", "Bordeaux", "Toulouse", 
    "Granada", "Bilbao", "Santander", "Alicante", "Zaragoza", 
    "Bruges", "Ghent", "Antwerp", "Rotterdam", "The Hague", 
    "Geneva", "Basel", "Lucerne", "Salzburg", "Innsbruck", 
    "Krakow", "Gdansk", "Wroclaw", "Poznan", "Lodz", 
    "Sofia", "Bucharest", "Belgrade", "Ljubljana", "Zagreb", 
    "Sarajevo", "Skopje", "Podgorica", "Tirana", "Vilnius", 
    "Riga", "Tallinn", "Minsk", "Saint Petersburg", "Moscow", 
    "Kyiv", "Odessa", "Chisinau", "Nicosia", "Valletta", 
    "Luxembourg", "Monaco", "San Marino", "Andorra la Vella", "Vaduz", 
    "Edinburgh", "Glasgow", "Cardiff", "Belfast", "Porto", 
    "Bratislava", "Kosice", "Split", "Dubrovnik", "Sibiu"
]

n = len(cities)
A = 10
B = 10
C = 1
distances = {}
for cindex1 in range(len(cities)-1):
    c1 = cities[cindex1]
    for cindex2 in range(cindex1+1,len(cities)):
        c2 = cities[cindex2]
        distances[c1,c2] = random.randint(1,6)
        distances[c2,c1] = distances[c1,c2]

#distances2 = {}
#distances2 = np.zeros((n, n), dtype=int)
#for i in range(n):
 #   for j in range(i + 1, n):
#        distances2[i, j] = distances2[j, i] = random.randint(1, 6)

#print("Distance Matrix:")
#print(distances2)

print(distances)

distance_matrix = np.zeros((n, n), dtype=int)
for (c1, c2), dist in distances.items():
    i, j = cities.index(c1), cities.index(c2)
    distance_matrix[i, j] = distance_matrix[j, i] = dist

print("Distance Matrix:")
print(distance_matrix)
# Out:
# {('Munich', 'Hamburg'): 6, ('Hamburg', 'Munich'): 6, ('Munich', 'Stuttgart'): 1, ('Stuttgart', 'Munich'): 1, ('Munich', 'Berlin'): 1, ('Berlin', 'Munich'): 1, ('Munich', 'Frankfurt'): 6, ('Frankfurt', 'Munich'): 6, ('Munich', 'Paris'): 3, ('Paris', 'Munich'): 3, ('Munich', 'Madrid'): 2, ('Madrid', 'Munich'): 2, ('Munich', 'Barcelona'): 2, ('Barcelona', 'Munich'): 2, ('Munich', 'Tenerife'): 2, ('Tenerife', 'Munich'): 2, ('Munich', 'Malaga'): 6, ('Malaga', 'Munich'): 6, ('Munich', 'Valencia'): 1, ('Valencia', 'Munich'): 1, ('Munich', 'Sevilla'): 6, ('Sevilla', 'Munich'): 6, ('Munich', 'Lisboa'): 6, ('Lisboa', 'Munich'): 6, ('Munich', 'Roma'): 5, ('Roma', 'Munich'): 5, ('Munich', 'London'): 1, ('London', 'Munich'): 1, ('Munich', 'Brussels'): 5, ('Brussels', 'Munich'): 5, ('Munich', 'Amsterdam'): 4, ('Amsterdam', 'Munich'): 4, ('Munich', 'Zurich'): 1, ('Zurich', 'Munich'): 1, ('Munich', 'Vienna'): 1, ('Vienna', 'Munich'): 1, ('Munich', 'Prague'): 1, ('Prague', 'Munich'): 1, ('Munich', 'Warsaw'): 2, ('Warsaw', 'Munich'): 2, ('Munich', 'Budapest'): 2, ('Budapest', 'Munich'): 2, ('Munich', 'Athens'): 5, ('Athens', 'Munich'): 5, ('Munich', 'Dublin'): 5, ('Dublin', 'Munich'): 5, ('Munich', 'Copenhagen'): 1, ('Copenhagen', 'Munich'): 1, ('Munich', 'Oslo'): 5, ('Oslo', 'Munich'): 5, ('Munich', 'Stockholm'): 2, ('Stockholm', 'Munich'): 2, ('Munich', 'Helsinki'): 6, ('Helsinki', 'Munich'): 6, ('Munich', 'Reykjavik'): 6, ('Reykjavik', 'Munich'): 6, ('Munich', 'Milan'): 6, ('Milan', 'Munich'): 6, ('Munich', 'Venice'): 5, ('Venice', 'Munich'): 5, ('Munich', 'Naples'): 4, ('Naples', 'Munich'): 4, ('Munich', 'Florence'): 2, ('Florence', 'Munich'): 2, ('Munich', 'Turin'): 4, ('Turin', 'Munich'): 4, ('Munich', 'Nice'): 5, ('Nice', 'Munich'): 5, ('Munich', 'Lyon'): 3, ('Lyon', 'Munich'): 3, ('Munich', 'Marseille'): 1, ('Marseille', 'Munich'): 1, ('Munich', 'Bordeaux'): 2, ('Bordeaux', 'Munich'): 2, ('Munich', 'Toulouse'): 6, ('Toulouse', 'Munich'): 6, ('Munich', 'Granada'): 4, ('Granada', 'Munich'): 4, ('Munich', 'Bilbao'): 3, ('Bilbao', 'Munich'): 3, ('Munich', 'Santander'): 3, ('Santander', 'Munich'): 3, ('Munich', 'Alicante'): 2, ('Alicante', 'Munich'): 2, ('Munich', 'Zaragoza'): 2, ('Zaragoza', 'Munich'): 2, ('Munich', 'Bruges'): 3, ('Bruges', 'Munich'): 3, ('Munich', 'Ghent'): 1, ('Ghent', 'Munich'): 1, ('Munich', 'Antwerp'): 1, ('Antwerp', 'Munich'): 1, ('Munich', 'Rotterdam'): 4, ('Rotterdam', 'Munich'): 4, ('Munich', 'The Hague'): 1, ('The Hague', 'Munich'): 1, ('Munich', 'Geneva'): 3, ('Geneva', 'Munich'): 3, ('Munich', 'Basel'): 3, ('Basel', 'Munich'): 3, ('Munich', 'Lucerne'): 5, ('Lucerne', 'Munich'): 5, ('Munich', 'Salzburg'): 3, ('Salzburg', 'Munich'): 3, ('Munich', 'Innsbruck'): 1, ('Innsbruck', 'Munich'): 1, ('Munich', 'Krakow'): 6, ('Krakow', 'Munich'): 6, ('Munich', 'Gdansk'): 4, ('Gdansk', 'Munich'): 4, ('Munich', 'Wroclaw'): 5, ('Wroclaw', 'Munich'): 5, ('Munich', 'Poznan'): 1, ('Poznan', 'Munich'): 1, ('Munich', 'Lodz'): 4, ('Lodz', 'Munich'): 4, ('Munich', 'Sofia'): 1, ('Sofia', 'Munich'): 1, ('Munich', 'Bucharest'): 5, ('Bucharest', 'Munich'): 5, ('Munich', 'Belgrade'): 3, ('Belgrade', 'Munich'): 3, ('Munich', 'Ljubljana'): 6, ('Ljubljana', 'Munich'): 6, ('Munich', 'Zagreb'): 5, ('Zagreb', 'Munich'): 5, ('Munich', 'Sarajevo'): 3, ('Sarajevo', 'Munich'): 3, ('Munich', 'Skopje'): 5, ('Skopje', 'Munich'): 5, ('Munich', 'Podgorica'): 2, ('Podgorica', 'Munich'): 2, ('Munich', 'Tirana'): 6, ('Tirana', 'Munich'): 6, ('Munich', 'Vilnius'): 1, ('Vilnius', 'Munich'): 1, ('Munich', 'Riga'): 1, ('Riga', 'Munich'): 1, ('Munich', 'Tallinn'): 6, ('Tallinn', 'Munich'): 6, ('Munich', 'Minsk'): 2, ('Minsk', 'Munich'): 2, ('Munich', 'Saint Petersburg'): 3, ('Saint Petersburg', 'Munich'): 3, ('Munich', 'Moscow'): 1, ('Moscow', 'Munich'): 1, ('Munich', 'Kyiv'): 2, ('Kyiv', 'Munich'): 2, ('Munich', 'Odessa'): 1, ('Odessa', 'Munich'): 1, ('Munich', 'Chisinau'): 4, ('Chisinau', 'Munich'): 4, ('Munich', 'Nicosia'): 3, ('Nicosia', 'Munich'): 3, ('Mun ...
# Distance Matrix:
# [[0 6 1 ... 5 6 2]
#  [6 0 5 ... 6 5 5]
#  [1 5 0 ... 4 3 4]
#  ...
#  [5 6 4 ... 0 5 4]
#  [6 5 3 ... 5 0 3]
#  [2 5 4 ... 4 3 0]]

# %% [raw]
# ### Restricciones

# %%
import dimod


solver = pywraplp.Solver.CreateSolver('SCIP')
if not solver:
    raise Exception("Solver no disponible.")
x = {}
for i in range(n):
    for j in range(n):
        if i != j:
            x[i, j] = solver.BoolVar(f'x[{i},{j}]')

# Variables para el sub-tour elimination
u = {}
for i in range(1, n):
    u[i] = solver.IntVar(0, n-1, f'u[{i}]')

# Restricciones
# Cada ciudad debe ser visitada exactamente una vez
for i in range(n):
    solver.Add(solver.Sum([x[i, j] for j in range(n) if i != j]) == 1)
    solver.Add(solver.Sum([x[j, i] for j in range(n) if i != j]) == 1)

# Sub-tour elimination constraints
for i in range(1, n):
    for j in range(1, n):
        if i != j:
            solver.Add(u[i] - u[j] + n * x[i, j] <= n - 1)

# %% [markdown]
# ### Resultados

# %%
import time
import psutil
def get_memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 / 1024  # Convertir a MB


# Función objetivo
solver.Minimize(solver.Sum([distance_matrix[i, j] * x[i, j] for i in range(n) for j in range(n) if i != j]))

initial_memory = get_memory_usage()

start_time = time.time()

# Resolver el problema
status = solver.Solve()
end_time = time.time()
final_memory = get_memory_usage()

# Obtener la solución
if status == pywraplp.Solver.OPTIMAL:
    route = []
    for i in range(n):
        for j in range(n):
            if i != j and x[i, j].solution_value() > 0.5:
                route.append((i, j))
    sorted_route = [0]
    while len(sorted_route) < n:
        for (i, j) in route:
            if i == sorted_route[-1]:
                sorted_route.append(j)
                break
    sorted_route.append(sorted_route[0])
    total_distance = sum(distance_matrix[sorted_route[i], sorted_route[i + 1]] for i in range(n))

    print("La ruta óptima es:", [cities[i] for i in sorted_route])
    print("Distancia total recorrida:", total_distance)
else:
    print("No se encontró solución óptima.")

print("Tiempo de ejecución:", end_time - start_time, "segundos")
print("Uso de memoria inicial:", initial_memory, "MB")
print("Uso de memoria final:", final_memory, "MB")
print("Incremento de uso de memoria:", final_memory - initial_memory, "MB")
# Out:
# pressed CTRL-C 1 times (5 times for forcing termination)

# %% [markdown]
# ### Draw Solution

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para visualizar la ruta y las distancias entre ciudades
def plot_route(route, cities, distance_matrix):
    n = len(cities)
    plt.figure(figsize=(10, 10))  # Aumentar el tamaño del gráfico
    ax = plt.gca()

    # Coordenadas de las ciudades (para visualización)
    coords = np.random.rand(n, 2) * 100  # Coordenadas aleatorias en un plano 100x100
    for i, (x, y) in enumerate(coords):
        ax.plot(x, y, 'o', markersize=10, label=cities[i])
        ax.text(x, y, f' {cities[i]}', fontsize=12)

    # Dibujar la ruta y añadir las distancias
    total_distance = 0
    for i in range(n):
        start_city = route[i]
        end_city = route[(i + 1) % n]
        start_coord = coords[start_city]
        end_coord = coords[end_city]
        ax.plot([start_coord[0], end_coord[0]], [start_coord[1], end_coord[1]], 'k-')
        
        # Calcular el punto medio para poner la etiqueta de la distancia
        mid_point = (start_coord + end_coord) / 2
        distance = distance_matrix[start_city, end_city]
        total_distance += distance
        
        # Ajustar posición de la etiqueta para que no se solape
        label_offset = np.array([0, 0])  # Ajuste vertical
        if start_coord[0] > end_coord[0]:
            label_offset[0] = -15  # Ajuste horizontal si necesario
        ax.text(mid_point[0] + label_offset[0], mid_point[1] + label_offset[1], 
                f'{distance}', color='red', fontsize=10, ha='center')

    # Dibujar la línea de regreso a la ciudad inicial
    start_city = route[0]
    start_coord = coords[start_city]
    end_coord = coords[route[-1]]
    ax.plot([start_coord[0], end_coord[0]], [start_coord[1], end_coord[1]], 'k-')

    plt.title(f"Ruta Óptima del Viajante - Distancia Total: {total_distance}")
    plt.legend()
    plt.grid(True)
    plt.show()

# Llamar a la función para dibujar la ruta con distancias
plot_route(sorted_route, cities, distance_matrix)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
